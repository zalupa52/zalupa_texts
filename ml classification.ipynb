# %% [markdown]
# # TfidfVectorizer

# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from catboost import CatBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('train.csv', sep='\t', index_col=0)
df
# Out:
#           Score                                               Text
# idx
# 0      Positive  В Альфа-Банке работает замечательная девушка -...
# 1      Negative  Оформляя рассрочку в м. Видео в меге тёплый ст...
# 2      Positive  Очень порадовала оперативность работы в банке....
# 3      Negative  Имела неосторожность оформить потреб. кредит в...
# 4      Negative  Небольшая предыстория: Нашел на сайте MDM банк...
# ...         ...                                                ...
# 13994  Positive  О высокой надёжности МКБ, порядочности и добро...
# 13995  Positive  Обслуживаюсь в офисе на Чернореченской 42а, ка...
# 13996  Positive  Попала сегодня в очень неприятную ситуацию. Ре...
# 13997  Positive  Добрый день! Давно являюсь клиентом банка Русс...
# 13998  Negative  Сначала было все банально. Взял в кредит mp3 п...
#
# [13999 rows x 2 columns]

# %%
le = LabelEncoder()
df['Score'] = le.fit_transform(df['Score'])
df
# Out:
#        Score                                               Text
# idx
# 0          1  В Альфа-Банке работает замечательная девушка -...
# 1          0  Оформляя рассрочку в м. Видео в меге тёплый ст...
# 2          1  Очень порадовала оперативность работы в банке....
# 3          0  Имела неосторожность оформить потреб. кредит в...
# 4          0  Небольшая предыстория: Нашел на сайте MDM банк...
# ...      ...                                                ...
# 13994      1  О высокой надёжности МКБ, порядочности и добро...
# 13995      1  Обслуживаюсь в офисе на Чернореченской 42а, ка...
# 13996      1  Попала сегодня в очень неприятную ситуацию. Ре...
# 13997      1  Добрый день! Давно являюсь клиентом банка Русс...
# 13998      0  Сначала было все банально. Взял в кредит mp3 п...
#
# [13999 rows x 2 columns]

# %%
df.isna().sum()
# Out:
# Score    0
# Text     0
# dtype: int64

# %%
vectorizer = TfidfVectorizer(stop_words='english', max_df=0.7)
X = vectorizer.fit_transform(df['Text'])
X
# Out:
# <13999x106454 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2171131 stored elements in Compressed Sparse Row format>

# %%
y = np.array(df['Score'])
y
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.01)

# %% [markdown]
# ## SVC

# %%
svc = SVC(kernel='linear')
svc.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svc.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9642857142857143

# %% [markdown]
# ## random forest

# %%
rfc_rs = GridSearchCV(
    estimator=RandomForestClassifier(),
    param_grid={
        # 'n_estimators': [20, 50, 100, 200, 250, 300],
        'n_estimators': [20, 50, 100],
        # 'max_depth': [7, 8, 10, 20, 25, None],
        'max_depth': [10, 20, None],
        'max_features': ['sqrt', 'log2', None],
        'criterion': ['gini', 'entropy', 'log_loss'],
        # 'min_samples_split': [1, 2, 5, 10],
        'min_samples_split': [1, 5],
        'n_jobs': [-1]
    },
    scoring='f1',
    verbose=52,
    cv=2
)
rfc_rs.fit(X, y)
# Out:
# Fitting 2 folds for each of 162 candidates, totalling 324 fits
# [CV 1/2; 1/162] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 1/162] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 1/162] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 1/162] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 2/162] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 2/162] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 2/162] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 2/162] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 3/162] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 3/162] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 3/162] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 3/162] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 4/162] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 4/162] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.827 total time=   0.2s
# [CV 2/2; 4/162] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 4/162] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.844 total time=   0.2s
# [CV 1/2; 5/162] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 5/162] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.878 total time=   0.4s
# [CV 2/2; 5/162] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 5/162] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.887 total time=   0.5s
# [CV 1/2; 6/162] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 6/162] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.889 total time=   0.7s
# [CV 2/2; 6/162] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 6/162] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.893 total time=   0.7s
# [CV 1/2; 7/162] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 7/162] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 7/162] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 7/162] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 8/162] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 8/162] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 8/162] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 8/162] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 9/162] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 9/162] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 9/162] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 9/162] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 10/162] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 10/162] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.686 total time=   0.1s
# [CV 2/2; 10/162] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 10/162] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.717 total time=   0.1s
# [CV 1/2; 11/162] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 11/162] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.798 total time=   0.2s
# [CV 2/2; 11/162] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 11/162] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.770 total time=   0.2s
# [CV 1/2; 12/162] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 12/162] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.791 total time=   0.4s
# [CV 2/2; 12/162] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 12/162] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.809 total time=   0.4s
# [CV 1/2; 13/162] START criterion=gini, max_depth=10, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 13/162] END criterion=gini, max_depth=10, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 13/162] START criterion=gini, max_depth=10, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 13/162] END criterion=gini, max_depth=10, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 14/162] START criterion=gini, max_depth=10, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 14/162] END criterion=gini, max_depth=10, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 14/162] START criterion=gini, max_depth=10, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 14/162] END criterion=gini, max_depth=10, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 15/162] START criterion=gini, max_depth=10, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 15/162] END criterion=gini, max_depth=10, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 15/162] START criterion=gini, max_depth=10, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 15/162] END criterion=gini, max_depth=10, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 16/162] START criterion=gini, max_depth=10, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 16/162] END criterion=gini, max_depth=10, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.843 total time=   6.5s
# [CV 2/2; 16/162] START criterion=gini, max_depth=10, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 16/162] END criterion=gini, max_depth=10, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.841 total time=   6.5s
# [CV 1/2; 17/162] START criterion=gini, max_depth=10, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 17/162] END criterion=gini, max_depth=10, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.845 total time=  14.0s
# [CV 2/2; 17/162] START criterion=gini, max_depth=10, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 17/162] END criterion=gini, max_depth=10, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.841 total time=  14.0s
# [CV 1/2; 18/162] START criterion=gini, max_depth=10, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 18/162] END criterion=gini, max_depth=10, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.846 total time=  25.6s
# [CV 2/2; 18/162] START criterion=gini, max_depth=10, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 18/162] END criterion=gini, max_depth=10, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.840 total time=  25.6s
# [CV 1/2; 19/162] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 19/162] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 19/162] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 19/162] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 20/162] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 20/162] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 20/162] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 20/162] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 21/162] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 21/162] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 21/162] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 21/162] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 22/162] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 22/162] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.869 total time=   0.3s
# [CV 2/2; 22/162] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 22/162] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.858 total time=   0.4s
# [CV 1/2; 23/162] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 23/162] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.886 total time=   0.6s
# [CV 2/2; 23/162] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 23/162] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.893 total time=   0.7s
# [CV 1/2; 24/162] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 24/162] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.900 total time=   1.2s
# [CV 2/2; 24/162] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 24/162] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.909 total time=   1.1s
# [CV 1/2; 25/162] START criterion=gini, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 25/162] END criterion=gini, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 25/162] START criterion=gini, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 25/162] END criterion=gini, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 26/162] START criterion=gini, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 26/162] END criterion=gini, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 26/162] START criterion=gini, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 26/162] END criterion=gini, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 27/162] START criterion=gini, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 27/162] END criterion=gini, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 27/162] START criterion=gini, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 27/162] END criterion=gini, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 28/162] START criterion=gini, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 28/162] END criterion=gini, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.721 total time=   0.1s
# [CV 2/2; 28/162] START criterion=gini, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 28/162] END criterion=gini, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.729 total time=   0.1s
# [CV 1/2; 29/162] START criterion=gini, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 29/162] END criterion=gini, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.798 total time=   0.2s
# [CV 2/2; 29/162] START criterion=gini, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 29/162] END criterion=gini, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.784 total time=   0.2s
# [CV 1/2; 30/162] START criterion=gini, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 30/162] END criterion=gini, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.848 total time=   0.4s
# [CV 2/2; 30/162] START criterion=gini, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 30/162] END criterion=gini, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.844 total time=   0.4s
# [CV 1/2; 31/162] START criterion=gini, max_depth=20, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 31/162] END criterion=gini, max_depth=20, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 31/162] START criterion=gini, max_depth=20, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 31/162] END criterion=gini, max_depth=20, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 32/162] START criterion=gini, max_depth=20, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 32/162] END criterion=gini, max_depth=20, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 32/162] START criterion=gini, max_depth=20, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 32/162] END criterion=gini, max_depth=20, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 33/162] START criterion=gini, max_depth=20, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 33/162] END criterion=gini, max_depth=20, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 33/162] START criterion=gini, max_depth=20, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 33/162] END criterion=gini, max_depth=20, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 34/162] START criterion=gini, max_depth=20, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 34/162] END criterion=gini, max_depth=20, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.869 total time=  10.2s
# [CV 2/2; 34/162] START criterion=gini, max_depth=20, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 34/162] END criterion=gini, max_depth=20, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.861 total time=  10.1s
# [CV 1/2; 35/162] START criterion=gini, max_depth=20, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 35/162] END criterion=gini, max_depth=20, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.870 total time=  22.0s
# [CV 2/2; 35/162] START criterion=gini, max_depth=20, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 35/162] END criterion=gini, max_depth=20, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.862 total time=  22.2s
# [CV 1/2; 36/162] START criterion=gini, max_depth=20, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 36/162] END criterion=gini, max_depth=20, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.872 total time=  41.4s
# [CV 2/2; 36/162] START criterion=gini, max_depth=20, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 36/162] END criterion=gini, max_depth=20, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.866 total time=  41.1s
# [CV 1/2; 37/162] START criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 37/162] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 37/162] START criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 37/162] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 38/162] START criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 38/162] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 38/162] START criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 38/162] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 39/162] START criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 39/162] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 39/162] START criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 39/162] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 40/162] START criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 40/162] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.872 total time=   0.7s
# [CV 2/2; 40/162] START criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 40/162] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.878 total time=   0.7s
# [CV 1/2; 41/162] START criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 41/162] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.911 total time=   1.5s
# [CV 2/2; 41/162] START criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 41/162] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.910 total time=   1.5s
# [CV 1/2; 42/162] START criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 42/162] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.914 total time=   2.8s
# [CV 2/2; 42/162] START criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 42/162] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.913 total time=   2.8s
# [CV 1/2; 43/162] START criterion=gini, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 43/162] END criterion=gini, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 43/162] START criterion=gini, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 43/162] END criterion=gini, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 44/162] START criterion=gini, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 44/162] END criterion=gini, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 44/162] START criterion=gini, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 44/162] END criterion=gini, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 45/162] START criterion=gini, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 45/162] END criterion=gini, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 45/162] START criterion=gini, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 45/162] END criterion=gini, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 46/162] START criterion=gini, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 46/162] END criterion=gini, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.827 total time=   0.5s
# [CV 2/2; 46/162] START criterion=gini, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 46/162] END criterion=gini, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.831 total time=   0.5s
# [CV 1/2; 47/162] START criterion=gini, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 47/162] END criterion=gini, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.881 total time=   1.1s
# [CV 2/2; 47/162] START criterion=gini, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 47/162] END criterion=gini, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.886 total time=   1.1s
# [CV 1/2; 48/162] START criterion=gini, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 48/162] END criterion=gini, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.894 total time=   2.0s
# [CV 2/2; 48/162] START criterion=gini, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 48/162] END criterion=gini, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.896 total time=   1.8s
# [CV 1/2; 49/162] START criterion=gini, max_depth=None, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 49/162] END criterion=gini, max_depth=None, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 49/162] START criterion=gini, max_depth=None, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 49/162] END criterion=gini, max_depth=None, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 50/162] START criterion=gini, max_depth=None, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 50/162] END criterion=gini, max_depth=None, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 50/162] START criterion=gini, max_depth=None, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 50/162] END criterion=gini, max_depth=None, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 51/162] START criterion=gini, max_depth=None, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 51/162] END criterion=gini, max_depth=None, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 51/162] START criterion=gini, max_depth=None, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 51/162] END criterion=gini, max_depth=None, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 52/162] START criterion=gini, max_depth=None, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 52/162] END criterion=gini, max_depth=None, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.880 total time=  18.9s
# [CV 2/2; 52/162] START criterion=gini, max_depth=None, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 52/162] END criterion=gini, max_depth=None, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.872 total time=  21.4s
# [CV 1/2; 53/162] START criterion=gini, max_depth=None, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 53/162] END criterion=gini, max_depth=None, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.885 total time=  41.3s
# [CV 2/2; 53/162] START criterion=gini, max_depth=None, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 53/162] END criterion=gini, max_depth=None, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.879 total time=  43.3s
# [CV 1/2; 54/162] START criterion=gini, max_depth=None, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 54/162] END criterion=gini, max_depth=None, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.887 total time= 1.3min
# [CV 2/2; 54/162] START criterion=gini, max_depth=None, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 54/162] END criterion=gini, max_depth=None, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.878 total time= 1.3min
# [CV 1/2; 55/162] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 55/162] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 55/162] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 55/162] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 56/162] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 56/162] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 56/162] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 56/162] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 57/162] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 57/162] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 57/162] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 57/162] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 58/162] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 58/162] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.842 total time=   0.2s
# [CV 2/2; 58/162] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 58/162] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.840 total time=   0.2s
# [CV 1/2; 59/162] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 59/162] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.884 total time=   0.3s
# [CV 2/2; 59/162] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 59/162] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.888 total time=   0.3s
# [CV 1/2; 60/162] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 60/162] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.888 total time=   0.7s
# [CV 2/2; 60/162] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 60/162] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.896 total time=   0.8s
# [CV 1/2; 61/162] START criterion=entropy, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 61/162] END criterion=entropy, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 61/162] START criterion=entropy, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 61/162] END criterion=entropy, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 62/162] START criterion=entropy, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 62/162] END criterion=entropy, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 62/162] START criterion=entropy, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 62/162] END criterion=entropy, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 63/162] START criterion=entropy, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 63/162] END criterion=entropy, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 63/162] START criterion=entropy, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 63/162] END criterion=entropy, max_depth=10, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 64/162] START criterion=entropy, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 64/162] END criterion=entropy, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.677 total time=   0.1s
# [CV 2/2; 64/162] START criterion=entropy, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 64/162] END criterion=entropy, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.678 total time=   0.1s
# [CV 1/2; 65/162] START criterion=entropy, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 65/162] END criterion=entropy, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.739 total time=   0.2s
# [CV 2/2; 65/162] START criterion=entropy, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 65/162] END criterion=entropy, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.757 total time=   0.2s
# [CV 1/2; 66/162] START criterion=entropy, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 66/162] END criterion=entropy, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.814 total time=   0.3s
# [CV 2/2; 66/162] START criterion=entropy, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 66/162] END criterion=entropy, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.794 total time=   0.4s
# [CV 1/2; 67/162] START criterion=entropy, max_depth=10, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 67/162] END criterion=entropy, max_depth=10, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 67/162] START criterion=entropy, max_depth=10, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 67/162] END criterion=entropy, max_depth=10, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 68/162] START criterion=entropy, max_depth=10, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 68/162] END criterion=entropy, max_depth=10, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 68/162] START criterion=entropy, max_depth=10, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 68/162] END criterion=entropy, max_depth=10, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 69/162] START criterion=entropy, max_depth=10, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 69/162] END criterion=entropy, max_depth=10, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 69/162] START criterion=entropy, max_depth=10, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 69/162] END criterion=entropy, max_depth=10, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 70/162] START criterion=entropy, max_depth=10, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 70/162] END criterion=entropy, max_depth=10, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.832 total time=   7.4s
# [CV 2/2; 70/162] START criterion=entropy, max_depth=10, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 70/162] END criterion=entropy, max_depth=10, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.835 total time=   7.4s
# [CV 1/2; 71/162] START criterion=entropy, max_depth=10, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 71/162] END criterion=entropy, max_depth=10, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.835 total time=  16.3s
# [CV 2/2; 71/162] START criterion=entropy, max_depth=10, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 71/162] END criterion=entropy, max_depth=10, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.836 total time=  16.2s
# [CV 1/2; 72/162] START criterion=entropy, max_depth=10, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 72/162] END criterion=entropy, max_depth=10, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.840 total time=  30.1s
# [CV 2/2; 72/162] START criterion=entropy, max_depth=10, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 72/162] END criterion=entropy, max_depth=10, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.840 total time=  30.4s
# [CV 1/2; 73/162] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 73/162] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 73/162] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 73/162] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 74/162] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 74/162] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 74/162] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 74/162] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 75/162] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 75/162] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 75/162] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 75/162] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 76/162] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 76/162] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.879 total time=   0.3s
# [CV 2/2; 76/162] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 76/162] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.883 total time=   0.4s
# [CV 1/2; 77/162] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 77/162] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.903 total time=   0.6s
# [CV 2/2; 77/162] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 77/162] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.902 total time=   0.6s
# [CV 1/2; 78/162] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 78/162] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.906 total time=   1.0s
# [CV 2/2; 78/162] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 78/162] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.914 total time=   1.1s
# [CV 1/2; 79/162] START criterion=entropy, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 79/162] END criterion=entropy, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 79/162] START criterion=entropy, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 79/162] END criterion=entropy, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 80/162] START criterion=entropy, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 80/162] END criterion=entropy, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 80/162] START criterion=entropy, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 80/162] END criterion=entropy, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 81/162] START criterion=entropy, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 81/162] END criterion=entropy, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 81/162] START criterion=entropy, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 81/162] END criterion=entropy, max_depth=20, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 82/162] START criterion=entropy, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 82/162] END criterion=entropy, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.742 total time=   0.1s
# [CV 2/2; 82/162] START criterion=entropy, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 82/162] END criterion=entropy, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.754 total time=   0.1s
# [CV 1/2; 83/162] START criterion=entropy, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 83/162] END criterion=entropy, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.804 total time=   0.2s
# [CV 2/2; 83/162] START criterion=entropy, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 83/162] END criterion=entropy, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.791 total time=   0.2s
# [CV 1/2; 84/162] START criterion=entropy, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 84/162] END criterion=entropy, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.828 total time=   0.4s
# [CV 2/2; 84/162] START criterion=entropy, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 84/162] END criterion=entropy, max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.831 total time=   0.4s
# [CV 1/2; 85/162] START criterion=entropy, max_depth=20, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 85/162] END criterion=entropy, max_depth=20, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 85/162] START criterion=entropy, max_depth=20, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 85/162] END criterion=entropy, max_depth=20, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 86/162] START criterion=entropy, max_depth=20, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 86/162] END criterion=entropy, max_depth=20, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 86/162] START criterion=entropy, max_depth=20, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 86/162] END criterion=entropy, max_depth=20, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 87/162] START criterion=entropy, max_depth=20, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 87/162] END criterion=entropy, max_depth=20, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 87/162] START criterion=entropy, max_depth=20, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 87/162] END criterion=entropy, max_depth=20, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 88/162] START criterion=entropy, max_depth=20, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 88/162] END criterion=entropy, max_depth=20, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.870 total time=  11.2s
# ...
# [CV 1/2; 142/162] START criterion=log_loss, max_depth=20, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 142/162] END criterion=log_loss, max_depth=20, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.869 total time=  11.2s
# [CV 2/2; 142/162] START criterion=log_loss, max_depth=20, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 142/162] END criterion=log_loss, max_depth=20, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.858 total time=  11.5s
# [CV 1/2; 143/162] START criterion=log_loss, max_depth=20, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 143/162] END criterion=log_loss, max_depth=20, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.875 total time=  25.1s
# [CV 2/2; 143/162] START criterion=log_loss, max_depth=20, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 143/162] END criterion=log_loss, max_depth=20, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.869 total time=  25.4s
# [CV 1/2; 144/162] START criterion=log_loss, max_depth=20, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 144/162] END criterion=log_loss, max_depth=20, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.873 total time=  46.2s
# [CV 2/2; 144/162] START criterion=log_loss, max_depth=20, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 144/162] END criterion=log_loss, max_depth=20, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.865 total time=  46.9s
# [CV 1/2; 145/162] START criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 145/162] END criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 145/162] START criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 145/162] END criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 146/162] START criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 146/162] END criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 146/162] START criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 146/162] END criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 147/162] START criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 147/162] END criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 147/162] START criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 147/162] END criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 148/162] START criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 148/162] END criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.881 total time=   0.8s
# [CV 2/2; 148/162] START criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 148/162] END criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.886 total time=   0.7s
# [CV 1/2; 149/162] START criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 149/162] END criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.912 total time=   1.5s
# [CV 2/2; 149/162] START criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 149/162] END criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.909 total time=   1.5s
# [CV 1/2; 150/162] START criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 150/162] END criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.920 total time=   2.8s
# [CV 2/2; 150/162] START criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 150/162] END criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.919 total time=   3.0s
# [CV 1/2; 151/162] START criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 151/162] END criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 151/162] START criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 151/162] END criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 152/162] START criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 152/162] END criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 152/162] START criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 152/162] END criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 153/162] START criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 153/162] END criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 153/162] START criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 153/162] END criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 154/162] START criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 154/162] END criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.842 total time=   0.5s
# [CV 2/2; 154/162] START criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 154/162] END criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.839 total time=   0.5s
# [CV 1/2; 155/162] START criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 155/162] END criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.882 total time=   1.0s
# [CV 2/2; 155/162] START criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 155/162] END criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.889 total time=   1.1s
# [CV 1/2; 156/162] START criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 156/162] END criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.903 total time=   1.8s
# [CV 2/2; 156/162] START criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 156/162] END criterion=log_loss, max_depth=None, max_features=log2, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.899 total time=   1.8s
# [CV 1/2; 157/162] START criterion=log_loss, max_depth=None, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 1/2; 157/162] END criterion=log_loss, max_depth=None, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 157/162] START criterion=log_loss, max_depth=None, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1
# [CV 2/2; 157/162] END criterion=log_loss, max_depth=None, max_features=None, min_samples_split=1, n_estimators=20, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 158/162] START criterion=log_loss, max_depth=None, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 1/2; 158/162] END criterion=log_loss, max_depth=None, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 158/162] START criterion=log_loss, max_depth=None, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1
# [CV 2/2; 158/162] END criterion=log_loss, max_depth=None, max_features=None, min_samples_split=1, n_estimators=50, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 159/162] START criterion=log_loss, max_depth=None, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 1/2; 159/162] END criterion=log_loss, max_depth=None, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 2/2; 159/162] START criterion=log_loss, max_depth=None, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1
# [CV 2/2; 159/162] END criterion=log_loss, max_depth=None, max_features=None, min_samples_split=1, n_estimators=100, n_jobs=-1;, score=nan total time=   0.0s
# [CV 1/2; 160/162] START criterion=log_loss, max_depth=None, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 1/2; 160/162] END criterion=log_loss, max_depth=None, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.883 total time=  13.8s
# [CV 2/2; 160/162] START criterion=log_loss, max_depth=None, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1
# [CV 2/2; 160/162] END criterion=log_loss, max_depth=None, max_features=None, min_samples_split=5, n_estimators=20, n_jobs=-1;, score=0.872 total time=  14.6s
# [CV 1/2; 161/162] START criterion=log_loss, max_depth=None, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 1/2; 161/162] END criterion=log_loss, max_depth=None, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.884 total time=  31.0s
# [CV 2/2; 161/162] START criterion=log_loss, max_depth=None, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1
# [CV 2/2; 161/162] END criterion=log_loss, max_depth=None, max_features=None, min_samples_split=5, n_estimators=50, n_jobs=-1;, score=0.872 total time=  32.4s
# [CV 1/2; 162/162] START criterion=log_loss, max_depth=None, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/2; 162/162] END criterion=log_loss, max_depth=None, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.888 total time=  55.8s
# [CV 2/2; 162/162] START criterion=log_loss, max_depth=None, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/2; 162/162] END criterion=log_loss, max_depth=None, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1;, score=0.878 total time=  57.6s
# c:\Users\ffedo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 162 fits failed out of a total of 324.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 162 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\ffedo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\ffedo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\ffedo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\ffedo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of RandomForestClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\ffedo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1103: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan 0.83557819 0.8825418  0.89094716
#         nan        nan        nan 0.70166199 0.78422069 0.79983807
#         nan        nan        nan 0.84212168 0.84298631 0.84270677
#         nan        nan        nan 0.86338372 0.88932332 0.90450575
#         nan        nan        nan 0.72499315 0.79084843 0.84621927
#         nan        nan        nan 0.86509602 0.86630964 0.8689018
#         nan        nan        nan 0.8749472  0.91038683 0.91352344
#         nan        nan        nan 0.82880145 0.88377893 0.89482547
#         nan        nan        nan 0.87587393 0.88204063 0.88242371
#         nan        nan        nan 0.84082556 0.88588744 0.8922649
#         nan        nan        nan 0.67742365 0.74797944 0.80435366
#         nan        nan        nan 0.83355325 0.83546726 0.840285
#         nan        nan        nan 0.88134815 0.90239791 0.91035334
#         nan        nan        nan 0.74817629 0.79751239 0.82918372
#         nan        nan        nan 0.86519557 0.86698841 0.8689699
#         nan        nan        nan 0.89173552 0.90606278 0.91871373
#         nan        nan        nan 0.84026725 0.88194668 0.90005757
#         nan        nan        nan 0.87511173 0.88057122 0.88208322
#         nan        nan        nan 0.85812879 0.87722686 0.89411183
#         nan        nan        nan 0.69643835 0.73779571 0.79546083
#         nan        nan        nan 0.83718586 0.83958714 0.8361108
#         nan        nan        nan 0.86908754 0.9018303  0.90674201
#         nan        nan        nan 0.73870493 0.80090008 0.83528831
#         nan        nan        nan 0.86360987 0.87194204 0.86945651
#         nan        nan        nan 0.88342881 0.91013577 0.91977806
#         nan        nan        nan 0.84071481 0.8853316  0.90137694
#         nan        nan        nan 0.87728342 0.87802702 0.88301842]
#   warnings.warn(
# GridSearchCV(cv=2, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [10, 20, None],
#                          'max_features': ['sqrt', 'log2', None],
#                          'min_samples_split': [1, 5],
#                          'n_estimators': [20, 50, 100], 'n_jobs': [-1]},
#              scoring='f1', verbose=52)

# %%
y_pred = rfc_rs.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %% [markdown]
# ## knn

# %%
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred = knn.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8142857142857143

# %% [markdown]
# ## catboost

# %%
cat = CatBoostClassifier(iterations=1000, learning_rate=0.01, 
                         depth=4, verbose=200,  eval_metric='Accuracy',
                         l2_leaf_reg=4, od_wait=1000, use_best_model = True, task_type='GPU')
cat.fit(X_train, y_train, eval_set=(X_test, y_test))
# Out:
# 0:	learn: 0.7949347	test: 0.8071429	best: 0.8071429 (0)	total: 827ms	remaining: 13m 46s
# 200:	learn: 0.8585035	test: 0.8571429	best: 0.8571429 (130)	total: 1m 46s	remaining: 7m 3s
# 400:	learn: 0.8872935	test: 0.8785714	best: 0.8857143 (388)	total: 3m 27s	remaining: 5m 9s
# 600:	learn: 0.9041778	test: 0.8928571	best: 0.8928571 (419)	total: 5m 4s	remaining: 3m 22s
# 800:	learn: 0.9136301	test: 0.9000000	best: 0.9000000 (632)	total: 6m 41s	remaining: 1m 39s
# 999:	learn: 0.9229382	test: 0.9000000	best: 0.9000000 (632)	total: 8m 21s	remaining: 0us
# bestTest = 0.9
# bestIteration = 632
# Shrink model to first 633 iterations.

# %%
y_pred = cat.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9
